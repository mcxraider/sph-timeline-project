# %%
# Import necessary libraries
import os
import json
from dotenv import load_dotenv
from tqdm import trange

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Import libraries for working with language models and Google Gemini
from langchain_openai import ChatOpenAI, OpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
import google.generativeai as genai
from google.generativeai.types import HarmCategory, HarmBlockThreshold

# Install the google-generativeai package (uncomment the line below to run the installation)
# !pip install -U -q google-generativeai

# Set up the environment for plotting
# %matplotlib inline

# Load environment variables
load_dotenv()
GEMINI_KEY = os.environ.get('GEMINI_KEY')
genai.configure(api_key=GEMINI_KEY)

# %%
# Read the JSON string from the file
with open('../data_upload/single_timeline_trial.json', 'r', encoding='utf-8') as fin:
    timeline = json.load(fin)

# %%
timeline
# Out:
# [{'Date': '2020-09-27',
#   'Event': 'Azerbaijan launched a large-scale offensive against the self-proclaimed Republic of Artsakh (Nagorno-Karabakh), which resulted in a six-week war.',
#   'Article_id': '96moyhcopwdgflfi'},
#  {'Date': '2020-09-27',
#   'Event': 'The Second Karabakh War began, with Azerbaijan retaking control of several territories in Nagorno-Karabakh.',
#   'Article_id': 'vehvbiu65a6u2ryr'},
#  {'Date': '2020-09-27',
#   'Event': 'Azerbaijan regained control of swathes of territory in Nagorno-Karabakh and surrounding regions.',
#   'Article_id': 'bon7mzog28fpzkqk'},
#  {'Date': '2020-11-10',
#   'Event': 'A tripartite ceasefire agreement was signed between Armenia, Azerbaijan, and Russia, ending the 2020 Nagorno-Karabakh war.',
#   'Article_id': '96moyhcopwdgflfi'},
#  {'Date': '2020-11-10',
#   'Event': 'A ceasefire was signed between Armenia and Azerbaijan, with Nagorno-Karabakh being returned to Azerbaijani control.',
#   'Article_id': 'vehvbiu65a6u2ryr'},
#  {'Date': '2022-03-24',
#   'Event': 'Azerbaijan accuses Armenia of violating the ceasefire, sparking tensions between the two countries.',
#   'Article_id': 'm5vcc0dfsmuho41p'},
#  {'Date': '2022-08-03',
#   'Event': 'Clashes erupt between Armenian and Azerbaijani forces along the border, resulting in several casualties.',
#   'Article_id': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-03-24',
#   'Event': 'Azerbaijan launches a military operation in Nagorno-Karabakh, seeking to regain control of the disputed territory.',
#   'Article_id': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-03-24',
#   'Event': 'Armenia and Azerbaijan agree to a ceasefire, but fighting continues sporadically.',
#   'Article_id': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-03-27',
#   'Event': 'Russia deploys peacekeepers to Nagorno-Karabakh to monitor the ceasefire.',
#   'Article_id': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-07-20',
#   'Event': 'Azerbaijan announces the capture of several villages in Nagorno-Karabakh.',
#   'Article_id': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-08-03',
#   'Event': 'Azerbaijan launches a new offensive in Nagorno-Karabakh.',
#   'Article_id': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-08-04',
#   'Event': 'Azerbaijan and Armenia agree to a new ceasefire, but it is violated within hours.',
#   'Article_id': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-09-08',
#   'Event': 'Armenia accuses Azerbaijan of conducting a military build-up along the border of Nagorno-Karabakh and the Armenia-Azerbaijan border.',
#   'Article_id': 'x6bs26mxih4wjnvb'},
#  {'Date': '2023-09-08',
#   'Event': "Azerbaijan’s foreign ministry rejects Armenia's assertion and accuses Yerevan of conducting military and political provocations.",
#   'Article_id': 'x6bs26mxih4wjnvb'},
#  {'Date': '2023-09-08',
#   'Event': "Azerbaijan’s foreign policy adviser, Hikmet Hajiyev, confirms that Azerbaijan's armed forces are conducting pre-planned drills, but accuses Armenia of concentrating troops on the border and purchasing new weaponry systems.",
#   'Article_id': 'x6bs26mxih4wjnvb'},
#  {'Date': '2023-09-08',
#   'Event': "Russia criticizes Armenia's decision to host a joint exercise involving 85 US soldiers, stating that it does not contribute to stabilizing the situation in the region.",
#   'Article_id': 'x6bs26mxih4wjnvb'},
#  {'Date': '2023-09-11',
#   'Event': 'Separatists in Karabakh refused to accept the cargo of a Russian Red Cross truck carrying aid, despite a deal announced with ethnic Armenian separatists to open the route for the first time in decades.',
#   'Article_id': 'j40zdfvo5mm8yv3c'},
#  {'Date': '2023-09-12',
#   'Event': 'A Russian truck carrying food aid for Armenians in the Karabakh city of Khankendi set off via the Aghdam road, according to a Reuters witness and local media.',
#   'Article_id': 'j40zdfvo5mm8yv3c'},
#  {'Date': '2023-09-12',
#   'Event': 'Azerbaijan and Armenia agree to a third ceasefire, which is implemented with the support of Russia.',
#   'Article_id': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-09-19',
#   'Event': "Ethnic Armenian separatist authorities reported a major escalation of hostilities in Azerbaijan's Nagorno-Karabakh region.",
#   'Article_id': 'bon7mzog28fpzkqk'},
#  {'Date': '2023-09-20',
#   'Event': 'Azerbaijan regained control of Nagorno-Karabakh after a three-decade-long Armenian occupation.',
#   'Article_id': '96moyhcopwdgflfi'},
#  {'Date': '2023-09-20',
#   'Event': 'Azerbaijani President Ilham Aliyev said he had given a strict order to all military units that the Armenian population living in the Karabakh region should not be affected by the anti-terrorist measures and that the civilian population be protected.',
#   'Article_id': 'kgiisc7nhbtx8o7o'},
#  {'Date': '2023-09-20',
#   'Event': 'Thousands of Armenians gathered at the airport in Stepanakert, Nagorno-Karabakh, following a ceasefire agreement that would result in the surrender of separatist forces to Azerbaijan.',
#   'Article_id': '8pjpbua9arko3ovu'},
#  {'Date': '2023-09-20',
#   'Event': 'Several hundred protesters gathered in the Armenian capital to demand that the government do more to support ethnic Armenians in Nagorno-Karabakh.',
#   'Article_id': 'vehvbiu65a6u2ryr'},
#  {'Date': '2023-09-21',
#   'Event': 'Armenian Prime Minister Nikol Pashinyan urges peace after Azerbaijan retakes Karabakh.',
#   'Article_id': '9owr18ngmcvsob4x'},
#  {'Date': '2023-09-21',
#   'Event': "Azerbaijan's President Ilham Aliyev expresses willingness for wider peace negotiations with Armenia.",
#   'Article_id': '9owr18ngmcvsob4x'},
#  {'Date': '2023-09-21',
#   'Event': 'Pashinyan emphasizes the importance of peace for Armenian independence, sovereignty, and security.',
#   'Article_id': '9owr18ngmcvsob4x'},
#  {'Date': '2023-09-24',
#   'Event': 'The ethnic Armenian leadership of breakaway Nagorno-Karabakh says the terms of the ceasefire with Azerbaijan are being implemented, with work proceeding on the delivery of humanitarian aid and evacuation of the wounded.',
#   'Article_id': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-09-25',
#   'Event': 'Petya Grigoryan, a 69-year-old driver, fled his village in the Martakert district of Karabakh after it was heavily bombed by Azerbaijani armed forces. Grigoryan said there were two KAMAZ-truckloads full of civilian dead in the village and that they had no place to bury them. He and his family were among the first ethnic Armenians of Nagorno-Karabakh to make it to Armenia after a lightning 24-hour Azerbaijani military operation defeated the Karabakh Armenian forces.',
#   'Article_id': 'kgiisc7nhbtx8o7o'},
#  {'Date': '2023-09-27',
#   'Event': 'Azerbaijan vowed to prosecute the separatist leadership of Nagorno-Karabakh.',
#   'Article_id': '96moyhcopwdgflfi'},
#  {'Date': '2023-10-04',
#   'Event': "Four ex-leaders of Nagorno-Karabakh were detained by Azerbaijan's State Security Service and taken to Baku.",
#   'Article_id': '96moyhcopwdgflfi'},
#  {'Date': '2023-10-04',
#   'Event': 'Three other former leaders of Nagorno-Karabakh arrived safely in Armenia.',
#   'Article_id': '96moyhcopwdgflfi'}]

# %%
with open('../data_upload/df_retrieve.json', 'r', encoding='utf-8') as fin:
    data = json.load(fin)
retrieval = pd.DataFrame(data)
retrieval.head()
# Out:
#                  id                                               Text  \
# 0  x6bs26mxih4wjnvb  LONDON - Armenia and Azerbaijan accused each o...
# 1  96moyhcopwdgflfi  Four ex-leaders of Azerbaijan's formerly ethni...
# 2  j40zdfvo5mm8yv3c  A Russian truck carrying food aid for Armenian...
# 3  9owr18ngmcvsob4x  MOSCOW  -     Armenia needs to be "free of con...
# 4  kgiisc7nhbtx8o7o  GORIS, Armenia  -     After the village was bo...
#
#                                                Title  \
# 0  Azerbaijan, Armenia accuse each other of milit...
# 1  Four Karabakh leaders held in Azerbaijan, thre...
# 2  Russia truck sets off with food aid for Armeni...
# 3  Armenia needs peace, PM says after Azerbaijan ...
# 4  Fleeing bombs and death, Karabakh Armenians re...
#
#                                           embeddings  \
# 0  [0.063698, -0.023136, 0.008678, 0.013113, -0.0...
# 1  [0.054137, -0.006537, 0.007394, 0.020186, -0.0...
# 2  [0.030952, -0.013953, -0.001719, 0.044435, -0....
# 3  [0.044655, 0.050847, -0.003256, -0.007795, -0....
# 4  [0.015886, -0.005729, 0.008714, -0.003721, -0....
#
#                                             combined  \
# 0  Title: Azerbaijan, Armenia accuse each other o...
# 1  Title: Four Karabakh leaders held in Azerbaija...
# 2  Title: Russia truck sets off with food aid for...
# 3  Title: Armenia needs peace, PM says after Azer...
# 4  Title: Fleeing bombs and death, Karabakh Armen...
#
#                                                 tags  \
# 0  [Armenia, Azerbaijan, Nagorno-Karabakh, Russia...
# 1  [Azerbaijan, Armenia, Nagorno-Karabakh, Ex-Kar...
# 2  [Russia, Armenia, Nagorno-Karabakh, Khankendi,...
# 3  [Armenia, Nagorno-Karabakh, Azerbaijan, Nikol ...
# 4  [Armenia, Karabakh, Azerbaijan, Refugees, Conf...
#
#                                      tags_embeddings  \
# 0  [0.03720000758767128, 0.010111724957823753, -0...
# 1  [0.04491448402404785, -0.0014135852688923478, ...
# 2  [0.040053002536296844, -0.0006843761657364666,...
# 3  [0.043720196932554245, 0.0023561876732856035, ...
# 4  [0.03360241651535034, 0.0005320683121681213, -...
#
#                                     Title_embeddings Publication_date  \
# 0  [0.035694, -0.013111, 0.013628, 0.005414, 0.01...       2023-09-08
# 1  [0.094126, -0.055465, -0.002879, 0.023244, -0....       2023-10-04
# 2  [0.03145, -0.020559, -0.000136, 0.045389, 0.00...       2023-09-12
# 3  [0.05158, 0.040333, -0.038155, -0.006117, -0.0...       2023-09-21
# 4  [0.031704, -0.012698, 0.001959, -0.060447, 0.0...       2023-09-25
#
#    Cluster_labels
# 0             523
# 1             523
# 2             523
# 3             523
# 4             523

# %% [markdown]
# ## Task Description:
# - Optimise the timeline by making it less dry and more contextually relevant.
# - Removing duplicates events and dates

# %%
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.pydantic_v1 import BaseModel, Field

llm = genai.GenerativeModel(model_name='gemini-1.5-flash-latest')

class Event(BaseModel):
    Date: str = Field(description="The date of the event in YYYY-MM-DD format")
    Event: str = Field(description="A detailed description of the event")
    Contextual_Annotation: str = Field(description="Conetextual Anecdotes of the event.")
    Article: str = Field(description="The article id from which the event was extracted")

parser = JsonOutputParser(pydantic_object=Event)

template = '''
You are given a timeline of events, your task is to enhance this timeline by improving its clarity, contextual information. 
If events occur on the same date and have similar descriptions, I want you to merge these events to avoid redundancy.
Add Contextual Annotations by providing brief annotations for major events to give additional context and improve understanding.
Only retain important information that would be value add when the general public reads the information.

Initial Timeline:
{text}

{format_instructions}
Ensure that the format follows the Example output format strictly before returning the output
'''
prompt = PromptTemplate(
    input_variables=["text"],
    template=template
)

# %%
final_prompt = prompt.format(text=timeline, format_instructions= parser.get_format_instructions())
response = llm.generate_content(final_prompt,
                                    safety_settings={
                                        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
                                        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
                                        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE, 
                                        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE
                                        }
    )

# %%
print(response.parts[0].text)
# Out:
# ```json
# [
#   {
#     "Date": "2020-09-27",
#     "Event": "Azerbaijan launched a large-scale offensive against the self-proclaimed Republic of Artsakh (Nagorno-Karabakh), resulting in a six-week war.",
#     "Contextual_Annotation": "This marked the beginning of the Second Karabakh War, a conflict rooted in the historical dispute over the Nagorno-Karabakh region.",
#     "Article": "96moyhcopwdgflfi"
#   },
#   {
#     "Date": "2020-11-10",
#     "Event": "A tripartite ceasefire agreement was signed between Armenia, Azerbaijan, and Russia, ending the 2020 Nagorno-Karabakh war.",
#     "Contextual_Annotation": "The ceasefire agreement resulted in Azerbaijan regaining control of significant territories in Nagorno-Karabakh and surrounding regions.",
#     "Article": "96moyhcopwdgflfi"
#   },
#   {
#     "Date": "2022-03-24",
#     "Event": "Azerbaijan accuses Armenia of violating the ceasefire, sparking tensions between the two countries.",
#     "Contextual_Annotation": "This marked a period of heightened tension following the ceasefire agreement, highlighting the fragility of the peace.",
#     "Article": "m5vcc0dfsmuho41p"
#   },
#   {
#     "Date": "2022-08-03",
#     "Event": "Clashes erupt between Armenian and Azerbaijani forces along the border, resulting in several casualties.",
#     "Contextual_Annotation": "Further escalation of tensions between Armenia and Azerbaijan, underscoring the ongoing dispute over the region.",
#     "Article": "m5vcc0dfsmuho41p"
#   },
#   {
#     "Date": "2023-03-24",
#     "Event": "Azerbaijan launches a military operation in Nagorno-Karabakh, seeking to regain control of the disputed territory.",
#     "Contextual_Annotation": "This marked a renewed escalation in the conflict, with Azerbaijan actively seeking to reclaim the contested region.",
#     "Article": "m5vcc0dfsmuho41p"
#   },
#   {
#     "Date": "2023-03-27",
#     "Event": "Russia deploys peacekeepers to Nagorno-Karabakh to monitor the ceasefire.",
#     "Contextual_Annotation": "Russia's role as a peacekeeper in the region is highlighted, aiming to maintain a fragile peace amidst ongoing tensions.",
#     "Article": "m5vcc0dfsmuho41p"
#   },
#   {
#     "Date": "2023-07-20",
#     "Event": "Azerbaijan announces the capture of several villages in Nagorno-Karabakh.",
#     "Contextual_Annotation": "This signifies a shift in the conflict, with Azerbaijan making territorial gains within the disputed region.",
#     "Article": "m5vcc0dfsmuho41p"
#   },
#   {
#     "Date": "2023-08-03",
#     "Event": "Azerbaijan launches a new offensive in Nagorno-Karabakh.",
#     "Contextual_Annotation": "This indicates an escalation of the conflict, with Azerbaijan pushing further into the disputed territory.",
#     "Article": "m5vcc0dfsmuho41p"
#   },
#   {
#     "Date": "2023-08-04",
#     "Event": "Azerbaijan and Armenia agree to a new ceasefire, but it is violated within hours.",
#     "Contextual_Annotation": "This highlights the fragility of any ceasefire agreements in the region, with ongoing hostilities despite attempts at peace.",
#     "Article": "m5vcc0dfsmuho41p"
#   },
#   {
#     "Date": "2023-09-08",
#     "Event": "Armenia accuses Azerbaijan of conducting a military build-up along the border of Nagorno-Karabakh and the Armenia-Azerbaijan border. Azerbaijan's foreign ministry rejects Armenia's assertion and accuses Yerevan of conducting military and political provocations. Azerbaijan's foreign policy adviser, Hikmet Hajiyev, confirms that Azerbaijan's armed forces are conducting pre-planned drills, but accuses Armenia of concentrating troops on the border and purchasing new weaponry systems. Russia criticizes Armenia's decision to host a joint exercise involving 85 US soldiers, stating that it does not contribute to stabilizing the situation in the region.",
#     "Contextual_Annotation": "This series of events highlights the growing tensions between Armenia and Azerbaijan, with both sides accusing each other of military provocations and seeking international support.",
#     "Article": "x6bs26mxih4wjnvb"
#   },
#   {
#     "Date": "2023-09-11",
#     "Event": "Separatists in Karabakh refused to accept the cargo of a Russian Red Cross truck carrying aid, despite a deal announced with ethnic Armenian separatists to open the route for the first time in decades.",
#     "Contextual_Annotation": "This incident showcases the complexity of the situation in Nagorno-Karabakh, with separatists rejecting humanitarian aid amidst tensions and ongoing conflict.",
#     "Article": "j40zdfvo5mm8yv3c"
#   },
#   {
#     "Date": "2023-09-12",
#     "Event": "A Russian truck carrying food aid for Armenians in the Karabakh city of Khankendi set off via the Aghdam road, according to a Reuters witness and local media. Azerbaijan and Armenia agree to a third ceasefire, which is implemented with the support of Russia.",
#     "Contextual_Annotation": "This signifies a breakthrough in humanitarian efforts and a renewed attempt at establishing a ceasefire between the two nations, with Russia playing a key role in mediating the agreement.",
#     "Article": "j40zdfvo5mm8yv3c"
#   },
#   {
#     "Date": "2023-09-19",
#     "Event": "Ethnic Armenian separatist authorities reported a major escalation of hostilities in Azerbaijan's Nagorno-Karabakh region.",
#     "Contextual_Annotation": "This marks a major turning point in the conflict, with renewed fighting and a significant escalation of hostilities.",
#     "Article": "bon7mzog28fpzkqk"
#   },
#   {
#     "Date": "2023-09-20",
#     "Event": "Azerbaijan regained control of Nagorno-Karabakh after a three-decade-long Armenian occupation. Azerbaijani President Ilham Aliyev said he had given a strict order to all military units that the Armenian population living in the Karabakh region should not be affected by the anti-terrorist measures and that the civilian population be protected. Thousands of Armenians gathered at the airport in Stepanakert, Nagorno-Karabakh, following a ceasefire agreement that would result in the surrender of separatist forces to Azerbaijan. Several hundred protesters gathered in the Armenian capital to demand that the government do more to support ethnic Armenians in Nagorno-Karabakh.",
#     "Contextual_Annotation": "This marks a significant shift in the power dynamic, with Azerbaijan reclaiming control of Nagorno-Karabakh after decades of conflict. This also highlights the humanitarian concerns and the reactions of the Armenian population.",
#     "Article": "96moyhcopwdgflfi"
#   },
#   {
#     "Date": "2023-09-21",
#     "Event": "Armenian Prime Minister Nikol Pashinyan urges peace after Azerbaijan retakes Karabakh. Azerbaijan's President Ilham Aliyev expresses willingness for wider peace negotiations with Armenia. Pashinyan emphasizes the importance of peace for Armenian independence, sovereignty, and security.",
#     "Contextual_Annotation": "This signifies a shift towards diplomatic efforts and a potential for peace negotiations between Armenia and Azerbaijan in the aftermath of the conflict.",
#     "Article": "9owr18ngmcvsob4x"
#   },
#   {
#     "Date": "2023-09-24",
#     "Event": "The ethnic Armenian leadership of breakaway Nagorno-Karabakh says the terms of the ceasefire with Azerbaijan are being implemented, with work proceeding on the delivery of humanitarian aid and evacuation of the wounded.",
#     "Contextual_Annotation": "This marks a step towards normalcy in the region, with the implementation of the ceasefire agreement and the provision of humanitarian aid.",
#     "Article": "m5vcc0dfsmuho41p"
#   },
#   {
#     "Date": "2023-09-25",
#     "Event": "Petya Grigoryan, a 69-year-old driver, fled his village in the Martakert district of Karabakh after it was heavily bombed by Azerbaijani armed forces. Grigoryan said there were two KAMAZ-truckloads full of civilian dead in the village and that they had no place to bury them. He and his family were among the first ethnic Armenians of Nagorno-Karabakh to make it to Armenia after a lightning 24-hour Azerbaijani military operation defeated the Karabakh Armenian forces.",
#     "Contextual_Annotation": "This provides a personal perspective on the impact of the conflict, highlighting the suffering and displacement of civilians amidst the fighting.",
#     "Article": "kgiisc7nhbtx8o7o"
#   },
#   {
#     "Date": "2023-09-27",
#     "Event": "Azerbaijan vowed to prosecute the separatist leadership of Nagorno-Karabakh.",
#     "Contextual_Annotation": "This indicates a shift in Azerbaijan's approach towards the separatists, aiming to hold them accountable for their actions during the conflict.",
#     "Article": "96moyhcopwdgflfi"
#   },
#   {
#     "Date": "2023-10-04",
#     "Event": "Four ex-leaders of Nagorno-Karabakh were detained by Azerbaijan's State Security Service and taken to Baku. Three other former leaders of Nagorno-Karabakh arrived safely in Armenia.",
#     "Contextual_Annotation": "This signifies Azerbaijan's efforts to address the leadership of the separatist movement following their victory in the conflict.",
#     "Article": "96moyhcopwdgflfi"
#   }
# ]
# ```

# %%
import re
enhanced_timeline = re.search(r'\[[^\]]*\]', response.parts[0].text).group(0)
enhanced_timeline
# Out:
# '[\n  {\n    "Date": "2020-09-27",\n    "Event": "Azerbaijan launched a large-scale offensive against the self-proclaimed Republic of Artsakh (Nagorno-Karabakh), resulting in a six-week war.",\n    "Contextual_Annotation": "This marked the beginning of the Second Karabakh War, a conflict rooted in the historical dispute over the Nagorno-Karabakh region.",\n    "Article": "96moyhcopwdgflfi"\n  },\n  {\n    "Date": "2020-11-10",\n    "Event": "A tripartite ceasefire agreement was signed between Armenia, Azerbaijan, and Russia, ending the 2020 Nagorno-Karabakh war.",\n    "Contextual_Annotation": "The ceasefire agreement resulted in Azerbaijan regaining control of significant territories in Nagorno-Karabakh and surrounding regions.",\n    "Article": "96moyhcopwdgflfi"\n  },\n  {\n    "Date": "2022-03-24",\n    "Event": "Azerbaijan accuses Armenia of violating the ceasefire, sparking tensions between the two countries.",\n    "Contextual_Annotation": "This marked a period of heightened tension following the ceasefire agreement, highlighting the fragility of the peace.",\n    "Article": "m5vcc0dfsmuho41p"\n  },\n  {\n    "Date": "2022-08-03",\n    "Event": "Clashes erupt between Armenian and Azerbaijani forces along the border, resulting in several casualties.",\n    "Contextual_Annotation": "Further escalation of tensions between Armenia and Azerbaijan, underscoring the ongoing dispute over the region.",\n    "Article": "m5vcc0dfsmuho41p"\n  },\n  {\n    "Date": "2023-03-24",\n    "Event": "Azerbaijan launches a military operation in Nagorno-Karabakh, seeking to regain control of the disputed territory.",\n    "Contextual_Annotation": "This marked a renewed escalation in the conflict, with Azerbaijan actively seeking to reclaim the contested region.",\n    "Article": "m5vcc0dfsmuho41p"\n  },\n  {\n    "Date": "2023-03-27",\n    "Event": "Russia deploys peacekeepers to Nagorno-Karabakh to monitor the ceasefire.",\n    "Contextual_Annotation": "Russia\'s role as a peacekeeper in the region is highlighted, aiming to maintain a fragile peace amidst ongoing tensions.",\n    "Article": "m5vcc0dfsmuho41p"\n  },\n  {\n    "Date": "2023-07-20",\n    "Event": "Azerbaijan announces the capture of several villages in Nagorno-Karabakh.",\n    "Contextual_Annotation": "This signifies a shift in the conflict, with Azerbaijan making territorial gains within the disputed region.",\n    "Article": "m5vcc0dfsmuho41p"\n  },\n  {\n    "Date": "2023-08-03",\n    "Event": "Azerbaijan launches a new offensive in Nagorno-Karabakh.",\n    "Contextual_Annotation": "This indicates an escalation of the conflict, with Azerbaijan pushing further into the disputed territory.",\n    "Article": "m5vcc0dfsmuho41p"\n  },\n  {\n    "Date": "2023-08-04",\n    "Event": "Azerbaijan and Armenia agree to a new ceasefire, but it is violated within hours.",\n    "Contextual_Annotation": "This highlights the fragility of any ceasefire agreements in the region, with ongoing hostilities despite attempts at peace.",\n    "Article": "m5vcc0dfsmuho41p"\n  },\n  {\n    "Date": "2023-09-08",\n    "Event": "Armenia accuses Azerbaijan of conducting a military build-up along the border of Nagorno-Karabakh and the Armenia-Azerbaijan border. Azerbaijan\'s foreign ministry rejects Armenia\'s assertion and accuses Yerevan of conducting military and political provocations. Azerbaijan\'s foreign policy adviser, Hikmet Hajiyev, confirms that Azerbaijan\'s armed forces are conducting pre-planned drills, but accuses Armenia of concentrating troops on the border and purchasing new weaponry systems. Russia criticizes Armenia\'s decision to host a joint exercise involving 85 US soldiers, stating that it does not contribute to stabilizing the situation in the region.",\n    "Contextual_Annotation": "This series of events highlights the growing tensions between Armenia and Azerbaijan, with both sides accusing each other of military provocations and seeking international support.",\n    "Article": " ...

# %%
data = json.loads(enhanced_timeline)
data
# Out:
# [{'Date': '2020-09-27',
#   'Event': 'Azerbaijan launched a large-scale offensive against the self-proclaimed Republic of Artsakh (Nagorno-Karabakh), resulting in a six-week war.',
#   'Contextual_Annotation': 'This marked the beginning of the Second Karabakh War, a conflict rooted in the historical dispute over the Nagorno-Karabakh region.',
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2020-11-10',
#   'Event': 'A tripartite ceasefire agreement was signed between Armenia, Azerbaijan, and Russia, ending the 2020 Nagorno-Karabakh war.',
#   'Contextual_Annotation': 'The ceasefire agreement resulted in Azerbaijan regaining control of significant territories in Nagorno-Karabakh and surrounding regions.',
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2022-03-24',
#   'Event': 'Azerbaijan accuses Armenia of violating the ceasefire, sparking tensions between the two countries.',
#   'Contextual_Annotation': 'This marked a period of heightened tension following the ceasefire agreement, highlighting the fragility of the peace.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2022-08-03',
#   'Event': 'Clashes erupt between Armenian and Azerbaijani forces along the border, resulting in several casualties.',
#   'Contextual_Annotation': 'Further escalation of tensions between Armenia and Azerbaijan, underscoring the ongoing dispute over the region.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-03-24',
#   'Event': 'Azerbaijan launches a military operation in Nagorno-Karabakh, seeking to regain control of the disputed territory.',
#   'Contextual_Annotation': 'This marked a renewed escalation in the conflict, with Azerbaijan actively seeking to reclaim the contested region.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-03-27',
#   'Event': 'Russia deploys peacekeepers to Nagorno-Karabakh to monitor the ceasefire.',
#   'Contextual_Annotation': "Russia's role as a peacekeeper in the region is highlighted, aiming to maintain a fragile peace amidst ongoing tensions.",
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-07-20',
#   'Event': 'Azerbaijan announces the capture of several villages in Nagorno-Karabakh.',
#   'Contextual_Annotation': 'This signifies a shift in the conflict, with Azerbaijan making territorial gains within the disputed region.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-08-03',
#   'Event': 'Azerbaijan launches a new offensive in Nagorno-Karabakh.',
#   'Contextual_Annotation': 'This indicates an escalation of the conflict, with Azerbaijan pushing further into the disputed territory.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-08-04',
#   'Event': 'Azerbaijan and Armenia agree to a new ceasefire, but it is violated within hours.',
#   'Contextual_Annotation': 'This highlights the fragility of any ceasefire agreements in the region, with ongoing hostilities despite attempts at peace.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-09-08',
#   'Event': "Armenia accuses Azerbaijan of conducting a military build-up along the border of Nagorno-Karabakh and the Armenia-Azerbaijan border. Azerbaijan's foreign ministry rejects Armenia's assertion and accuses Yerevan of conducting military and political provocations. Azerbaijan's foreign policy adviser, Hikmet Hajiyev, confirms that Azerbaijan's armed forces are conducting pre-planned drills, but accuses Armenia of concentrating troops on the border and purchasing new weaponry systems. Russia criticizes Armenia's decision to host a joint exercise involving 85 US soldiers, stating that it does not contribute to stabilizing the situation in the region.",
#   'Contextual_Annotation': 'This series of events highlights the growing tensions between Armenia and Azerbaijan, with both sides accusing each other of military provocations and seeking international support.',
#   'Article': 'x6bs26mxih4wjnvb'},
#  {'Date': '2023-09-11',
#   'Event': 'Separatists in Karabakh refused to accept the cargo of a Russian Red Cross truck carrying aid, despite a deal announced with ethnic Armenian separatists to open the route for the first time in decades.',
#   'Contextual_Annotation': 'This incident showcases the complexity of the situation in Nagorno-Karabakh, with separatists rejecting humanitarian aid amidst tensions and ongoing conflict.',
#   'Article': 'j40zdfvo5mm8yv3c'},
#  {'Date': '2023-09-12',
#   'Event': 'A Russian truck carrying food aid for Armenians in the Karabakh city of Khankendi set off via the Aghdam road, according to a Reuters witness and local media. Azerbaijan and Armenia agree to a third ceasefire, which is implemented with the support of Russia.',
#   'Contextual_Annotation': 'This signifies a breakthrough in humanitarian efforts and a renewed attempt at establishing a ceasefire between the two nations, with Russia playing a key role in mediating the agreement.',
#   'Article': 'j40zdfvo5mm8yv3c'},
#  {'Date': '2023-09-19',
#   'Event': "Ethnic Armenian separatist authorities reported a major escalation of hostilities in Azerbaijan's Nagorno-Karabakh region.",
#   'Contextual_Annotation': 'This marks a major turning point in the conflict, with renewed fighting and a significant escalation of hostilities.',
#   'Article': 'bon7mzog28fpzkqk'},
#  {'Date': '2023-09-20',
#   'Event': 'Azerbaijan regained control of Nagorno-Karabakh after a three-decade-long Armenian occupation. Azerbaijani President Ilham Aliyev said he had given a strict order to all military units that the Armenian population living in the Karabakh region should not be affected by the anti-terrorist measures and that the civilian population be protected. Thousands of Armenians gathered at the airport in Stepanakert, Nagorno-Karabakh, following a ceasefire agreement that would result in the surrender of separatist forces to Azerbaijan. Several hundred protesters gathered in the Armenian capital to demand that the government do more to support ethnic Armenians in Nagorno-Karabakh.',
#   'Contextual_Annotation': 'This marks a significant shift in the power dynamic, with Azerbaijan reclaiming control of Nagorno-Karabakh after decades of conflict. This also highlights the humanitarian concerns and the reactions of the Armenian population.',
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2023-09-21',
#   'Event': "Armenian Prime Minister Nikol Pashinyan urges peace after Azerbaijan retakes Karabakh. Azerbaijan's President Ilham Aliyev expresses willingness for wider peace negotiations with Armenia. Pashinyan emphasizes the importance of peace for Armenian independence, sovereignty, and security.",
#   'Contextual_Annotation': 'This signifies a shift towards diplomatic efforts and a potential for peace negotiations between Armenia and Azerbaijan in the aftermath of the conflict.',
#   'Article': '9owr18ngmcvsob4x'},
#  {'Date': '2023-09-24',
#   'Event': 'The ethnic Armenian leadership of breakaway Nagorno-Karabakh says the terms of the ceasefire with Azerbaijan are being implemented, with work proceeding on the delivery of humanitarian aid and evacuation of the wounded.',
#   'Contextual_Annotation': 'This marks a step towards normalcy in the region, with the implementation of the ceasefire agreement and the provision of humanitarian aid.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-09-25',
#   'Event': 'Petya Grigoryan, a 69-year-old driver, fled his village in the Martakert district of Karabakh after it was heavily bombed by Azerbaijani armed forces. Grigoryan said there were two KAMAZ-truckloads full of civilian dead in the village and that they had no place to bury them. He and his family were among the first ethnic Armenians of Nagorno-Karabakh to make it to Armenia after a lightning 24-hour Azerbaijani military operation defeated the Karabakh Armenian forces.',
#   'Contextual_Annotation': 'This provides a personal perspective on the impact of the conflict, highlighting the suffering and displacement of civilians amidst the fighting.',
#   'Article': 'kgiisc7nhbtx8o7o'},
#  {'Date': '2023-09-27',
#   'Event': 'Azerbaijan vowed to prosecute the separatist leadership of Nagorno-Karabakh.',
#   'Contextual_Annotation': "This indicates a shift in Azerbaijan's approach towards the separatists, aiming to hold them accountable for their actions during the conflict.",
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2023-10-04',
#   'Event': "Four ex-leaders of Nagorno-Karabakh were detained by Azerbaijan's State Security Service and taken to Baku. Three other former leaders of Nagorno-Karabakh arrived safely in Armenia.",
#   'Contextual_Annotation': "This signifies Azerbaijan's efforts to address the leadership of the separatist movement following their victory in the conflict.",
#   'Article': '96moyhcopwdgflfi'}]

# %%
from datetime import datetime
sorted_timeline = sorted(data, key=lambda x: datetime.strptime(x['Date'], '%Y-%m-%d'))
sorted_timeline
# Out:
# [{'Date': '2020-09-27',
#   'Event': 'Azerbaijan launched a large-scale offensive against the self-proclaimed Republic of Artsakh (Nagorno-Karabakh), resulting in a six-week war.',
#   'Contextual_Annotation': 'This marked the beginning of the Second Karabakh War, a conflict rooted in the historical dispute over the Nagorno-Karabakh region.',
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2020-11-10',
#   'Event': 'A tripartite ceasefire agreement was signed between Armenia, Azerbaijan, and Russia, ending the 2020 Nagorno-Karabakh war.',
#   'Contextual_Annotation': 'The ceasefire agreement resulted in Azerbaijan regaining control of significant territories in Nagorno-Karabakh and surrounding regions.',
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2022-03-24',
#   'Event': 'Azerbaijan accuses Armenia of violating the ceasefire, sparking tensions between the two countries.',
#   'Contextual_Annotation': 'This marked a period of heightened tension following the ceasefire agreement, highlighting the fragility of the peace.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2022-08-03',
#   'Event': 'Clashes erupt between Armenian and Azerbaijani forces along the border, resulting in several casualties.',
#   'Contextual_Annotation': 'Further escalation of tensions between Armenia and Azerbaijan, underscoring the ongoing dispute over the region.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-03-24',
#   'Event': 'Azerbaijan launches a military operation in Nagorno-Karabakh, seeking to regain control of the disputed territory.',
#   'Contextual_Annotation': 'This marked a renewed escalation in the conflict, with Azerbaijan actively seeking to reclaim the contested region.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-03-27',
#   'Event': 'Russia deploys peacekeepers to Nagorno-Karabakh to monitor the ceasefire.',
#   'Contextual_Annotation': "Russia's role as a peacekeeper in the region is highlighted, aiming to maintain a fragile peace amidst ongoing tensions.",
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-07-20',
#   'Event': 'Azerbaijan announces the capture of several villages in Nagorno-Karabakh.',
#   'Contextual_Annotation': 'This signifies a shift in the conflict, with Azerbaijan making territorial gains within the disputed region.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-08-03',
#   'Event': 'Azerbaijan launches a new offensive in Nagorno-Karabakh.',
#   'Contextual_Annotation': 'This indicates an escalation of the conflict, with Azerbaijan pushing further into the disputed territory.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-08-04',
#   'Event': 'Azerbaijan and Armenia agree to a new ceasefire, but it is violated within hours.',
#   'Contextual_Annotation': 'This highlights the fragility of any ceasefire agreements in the region, with ongoing hostilities despite attempts at peace.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-09-08',
#   'Event': "Armenia accuses Azerbaijan of conducting a military build-up along the border of Nagorno-Karabakh and the Armenia-Azerbaijan border. Azerbaijan's foreign ministry rejects Armenia's assertion and accuses Yerevan of conducting military and political provocations. Azerbaijan's foreign policy adviser, Hikmet Hajiyev, confirms that Azerbaijan's armed forces are conducting pre-planned drills, but accuses Armenia of concentrating troops on the border and purchasing new weaponry systems. Russia criticizes Armenia's decision to host a joint exercise involving 85 US soldiers, stating that it does not contribute to stabilizing the situation in the region.",
#   'Contextual_Annotation': 'This series of events highlights the growing tensions between Armenia and Azerbaijan, with both sides accusing each other of military provocations and seeking international support.',
#   'Article': 'x6bs26mxih4wjnvb'},
#  {'Date': '2023-09-11',
#   'Event': 'Separatists in Karabakh refused to accept the cargo of a Russian Red Cross truck carrying aid, despite a deal announced with ethnic Armenian separatists to open the route for the first time in decades.',
#   'Contextual_Annotation': 'This incident showcases the complexity of the situation in Nagorno-Karabakh, with separatists rejecting humanitarian aid amidst tensions and ongoing conflict.',
#   'Article': 'j40zdfvo5mm8yv3c'},
#  {'Date': '2023-09-12',
#   'Event': 'A Russian truck carrying food aid for Armenians in the Karabakh city of Khankendi set off via the Aghdam road, according to a Reuters witness and local media. Azerbaijan and Armenia agree to a third ceasefire, which is implemented with the support of Russia.',
#   'Contextual_Annotation': 'This signifies a breakthrough in humanitarian efforts and a renewed attempt at establishing a ceasefire between the two nations, with Russia playing a key role in mediating the agreement.',
#   'Article': 'j40zdfvo5mm8yv3c'},
#  {'Date': '2023-09-19',
#   'Event': "Ethnic Armenian separatist authorities reported a major escalation of hostilities in Azerbaijan's Nagorno-Karabakh region.",
#   'Contextual_Annotation': 'This marks a major turning point in the conflict, with renewed fighting and a significant escalation of hostilities.',
#   'Article': 'bon7mzog28fpzkqk'},
#  {'Date': '2023-09-20',
#   'Event': 'Azerbaijan regained control of Nagorno-Karabakh after a three-decade-long Armenian occupation. Azerbaijani President Ilham Aliyev said he had given a strict order to all military units that the Armenian population living in the Karabakh region should not be affected by the anti-terrorist measures and that the civilian population be protected. Thousands of Armenians gathered at the airport in Stepanakert, Nagorno-Karabakh, following a ceasefire agreement that would result in the surrender of separatist forces to Azerbaijan. Several hundred protesters gathered in the Armenian capital to demand that the government do more to support ethnic Armenians in Nagorno-Karabakh.',
#   'Contextual_Annotation': 'This marks a significant shift in the power dynamic, with Azerbaijan reclaiming control of Nagorno-Karabakh after decades of conflict. This also highlights the humanitarian concerns and the reactions of the Armenian population.',
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2023-09-21',
#   'Event': "Armenian Prime Minister Nikol Pashinyan urges peace after Azerbaijan retakes Karabakh. Azerbaijan's President Ilham Aliyev expresses willingness for wider peace negotiations with Armenia. Pashinyan emphasizes the importance of peace for Armenian independence, sovereignty, and security.",
#   'Contextual_Annotation': 'This signifies a shift towards diplomatic efforts and a potential for peace negotiations between Armenia and Azerbaijan in the aftermath of the conflict.',
#   'Article': '9owr18ngmcvsob4x'},
#  {'Date': '2023-09-24',
#   'Event': 'The ethnic Armenian leadership of breakaway Nagorno-Karabakh says the terms of the ceasefire with Azerbaijan are being implemented, with work proceeding on the delivery of humanitarian aid and evacuation of the wounded.',
#   'Contextual_Annotation': 'This marks a step towards normalcy in the region, with the implementation of the ceasefire agreement and the provision of humanitarian aid.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-09-25',
#   'Event': 'Petya Grigoryan, a 69-year-old driver, fled his village in the Martakert district of Karabakh after it was heavily bombed by Azerbaijani armed forces. Grigoryan said there were two KAMAZ-truckloads full of civilian dead in the village and that they had no place to bury them. He and his family were among the first ethnic Armenians of Nagorno-Karabakh to make it to Armenia after a lightning 24-hour Azerbaijani military operation defeated the Karabakh Armenian forces.',
#   'Contextual_Annotation': 'This provides a personal perspective on the impact of the conflict, highlighting the suffering and displacement of civilians amidst the fighting.',
#   'Article': 'kgiisc7nhbtx8o7o'},
#  {'Date': '2023-09-27',
#   'Event': 'Azerbaijan vowed to prosecute the separatist leadership of Nagorno-Karabakh.',
#   'Contextual_Annotation': "This indicates a shift in Azerbaijan's approach towards the separatists, aiming to hold them accountable for their actions during the conflict.",
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2023-10-04',
#   'Event': "Four ex-leaders of Nagorno-Karabakh were detained by Azerbaijan's State Security Service and taken to Baku. Three other former leaders of Nagorno-Karabakh arrived safely in Armenia.",
#   'Contextual_Annotation': "This signifies Azerbaijan's efforts to address the leadership of the separatist movement following their victory in the conflict.",
#   'Article': '96moyhcopwdgflfi'}]

# %%
unique_ids = []
for event in sorted_timeline:
    if event['Article'] not in unique_ids:
        unique_ids.append(event['Article'])
unique_ids
# Out:
# ['96moyhcopwdgflfi',
#  'm5vcc0dfsmuho41p',
#  'x6bs26mxih4wjnvb',
#  'j40zdfvo5mm8yv3c',
#  'bon7mzog28fpzkqk',
#  '9owr18ngmcvsob4x',
#  'kgiisc7nhbtx8o7o']

# %%
llm = genai.GenerativeModel(model_name='gemini-1.5-flash-latest')

template = '''
You are given a timeline of events, and an article related to this timeline. 
Your task is to reference the provided article and enhance this timeline by improving its clarity and contextual information.
Add to the Contextual Annotations by providing annotations for major events to give additional context and improve understanding, \
  however, ensure that the contextual annotations added do not blatantly repeat what the contents of the event.

Initial Timeline:
{timeline}

Reference Article:
{article}

{format_instructions}
Double check and ensure that the format follows the Example output format strictly before returning the output
'''
prompt = PromptTemplate(
    input_variables=["text", "article"],
    template=template
)

# %%
from json import JSONDecodeError
import re
import time

def clean_output(output):
    try:
        updated_timeline = json.loads(output)
        return updated_timeline
    except JSONDecodeError:
        #try 1: Ensuring that the string ends with just the open and close lists brackets
        output = re.search(r'\[[^\]]*\]', output).group(0)
        updated_timeline = json.loads(output)
        return updated_timeline

final_timeline = []
unique_ids = []
for event in sorted_timeline:
    if event['Article'] not in unique_ids:
        unique_ids.append(event['Article'])
for i in trange(len(unique_ids)):
    text = []
    for event in sorted_timeline:
        if event['Article'] == unique_ids[i]:
            text.append(event)
    article = retrieval[retrieval['id'] == unique_ids[i]].reset_index()['Text'][0]
    final_prompt = prompt.format(timeline=text, article = article, format_instructions=parser.get_format_instructions())
    response = llm.generate_content(final_prompt,
                                    safety_settings={
                                        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
                                        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
                                        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE, 
                                        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE
                                        }
    )
    section = clean_output(response.parts[0].text)
    final_timeline.append(section)
    time.sleep(5)

final_timeline
# Out:
# 100%|██████████| 7/7 [01:24<00:00, 12.07s/it]
# [[{'Date': '2020-09-27',
#    'Event': 'Azerbaijan launched a large-scale offensive against the self-proclaimed Republic of Artsakh (Nagorno-Karabakh), resulting in a six-week war.',
#    'Contextual_Annotation': 'This marked the beginning of the Second Karabakh War, a conflict rooted in the historical dispute over the Nagorno-Karabakh region. The war was a result of decades of unresolved tensions between Armenia and Azerbaijan over the region, which had been under Armenian control since the 1990s following the collapse of the Soviet Union.',
#    'Article': '96moyhcopwdgflfi'},
#   {'Date': '2020-11-10',
#    'Event': 'A tripartite ceasefire agreement was signed between Armenia, Azerbaijan, and Russia, ending the 2020 Nagorno-Karabakh war.',
#    'Contextual_Annotation': 'The ceasefire agreement resulted in Azerbaijan regaining control of significant territories in Nagorno-Karabakh and surrounding regions, including the city of Shusha, which is considered to be of great strategic and symbolic importance for Azerbaijan. The agreement also led to the deployment of Russian peacekeepers to the region to monitor the ceasefire and oversee the return of displaced persons.',
#    'Article': '96moyhcopwdgflfi'},
#   {'Date': '2023-09-20',
#    'Event': 'Azerbaijan regained control of Nagorno-Karabakh after a three-decade-long Armenian occupation. Azerbaijani President Ilham Aliyev said he had given a strict order to all military units that the Armenian population living in the Karabakh region should not be affected by the anti-terrorist measures and that the civilian population be protected. Thousands of Armenians gathered at the airport in Stepanakert, Nagorno-Karabakh, following a ceasefire agreement that would result in the surrender of separatist forces to Azerbaijan. Several hundred protesters gathered in the Armenian capital to demand that the government do more to support ethnic Armenians in Nagorno-Karabakh.',
#    'Contextual_Annotation': "This marked a significant shift in the power dynamic, with Azerbaijan reclaiming control of Nagorno-Karabakh after decades of conflict. This event was precipitated by the breakdown of the 2020 ceasefire agreement and Azerbaijan's swift military operation. The event also highlights the humanitarian concerns and the reactions of the Armenian population. Thousands of Armenians fled Nagorno-Karabakh to Armenia fearing for their safety, highlighting the complex and sensitive nature of the situation.",
#    'Article': '96moyhcopwdgflfi'},
#   {'Date': '2023-09-27',
#    'Event': 'Azerbaijan vowed to prosecute the separatist leadership of Nagorno-Karabakh.',
#    'Contextual_Annotation': "This indicates a shift in Azerbaijan's approach towards the separatists, aiming to hold them accountable for their actions during the conflict. Azerbaijan viewed the separatists as criminals and blamed them for poisoning the minds of the Armenian population.  This statement was made in the context of the swift military operation by Azerbaijan to regain control of Nagorno-Karabakh.",
#    'Article': '96moyhcopwdgflfi'},
#   {'Date': '2023-10-04',
#    'Event': "Four ex-leaders of Nagorno-Karabakh were detained by Azerbaijan's State Security Service and taken to Baku. Three other former leaders of Nagorno-Karabakh arrived safely in Armenia.",
#    'Contextual_Annotation': "This signifies Azerbaijan's efforts to address the leadership of the separatist movement following their victory in the conflict. The detention of former leaders, including ex-president Arkady Gukasyan, Bako Sahakyan, and Araik Arutyunyan, highlights Azerbaijan's determination to hold them accountable for their actions.  The safe arrival of three other former leaders, including Artur Arutyunyan,  in Armenia adds a layer of complexity to the situation and raises questions about the fate of other former separatist leaders.",
#    'Article': '96moyhcopwdgflfi'}],
#  [{'Date': '2022-03-24',
#    'Event': 'Azerbaijan accuses Armenia of violating the ceasefire, sparking tensions between the two countries.',
#    'Contextual_Annotation': 'This marked a period of heightened tension following the ceasefire agreement, highlighting the fragility of the peace established after the 2020 war.',
#    'Article': 'm5vcc0dfsmuho41p'},
#   {'Date': '2022-08-03',
#    'Event': 'Clashes erupt between Armenian and Azerbaijani forces along the border, resulting in several casualties.',
#    'Contextual_Annotation': 'Further escalation of tensions between Armenia and Azerbaijan, underscoring the ongoing dispute over the Nagorno-Karabakh region.',
#    'Article': 'm5vcc0dfsmuho41p'},
#   {'Date': '2023-03-24',
#    'Event': 'Azerbaijan launches a military operation in Nagorno-Karabakh, seeking to regain control of the disputed territory.',
#    'Contextual_Annotation': 'This marked a renewed escalation in the conflict, with Azerbaijan launching a lightning offensive to retake control of the mountainous region, which they claim as their own.',
#    'Article': 'm5vcc0dfsmuho41p'},
#   {'Date': '2023-03-27',
#    'Event': 'Russia deploys peacekeepers to Nagorno-Karabakh to monitor the ceasefire.',
#    'Contextual_Annotation': "Russia's role as a peacekeeper in the region is highlighted, aiming to maintain a fragile peace amidst ongoing tensions.  This deployment followed the ceasefire agreement brokered by Russia.",
#    'Article': 'm5vcc0dfsmuho41p'},
#   {'Date': '2023-07-20',
#    'Event': 'Azerbaijan announces the capture of several villages in Nagorno-Karabakh.',
#    'Contextual_Annotation': 'This signifies a shift in the conflict, with Azerbaijan making territorial gains within the disputed region.  This move followed a months-long de facto blockade of the region.',
#    'Article': 'm5vcc0dfsmuho41p'},
#   {'Date': '2023-08-03',
#    'Event': 'Azerbaijan launches a new offensive in Nagorno-Karabakh.',
#    'Contextual_Annotation': "This indicates a significant escalation of the conflict, with Azerbaijan pushing further into the disputed territory after capturing several villages. This was labeled an 'anti-terrorist' operation by Azerbaijan.",
#    'Article': 'm5vcc0dfsmuho41p'},
#   {'Date': '2023-08-04',
#    'Event': 'Azerbaijan and Armenia agree to a new ceasefire, but it is violated within hours.',
#    'Contextual_Annotation': 'This highlights the fragility of any ceasefire agreements in the region, with ongoing hostilities despite attempts at peace. This ceasefire followed the offensive launched by Azerbaijan.',
#    'Article': 'm5vcc0dfsmuho41p'},
#   {'Date': '2023-09-24',
#    'Event': 'The ethnic Armenian leadership of breakaway Nagorno-Karabakh says the terms of the ceasefire with Azerbaijan are being implemented, with work proceeding on the delivery of humanitarian aid and evacuation of the wounded.',
#    'Contextual_Annotation': 'This marks a step towards normalcy in the region, with the implementation of the ceasefire agreement and the provision of humanitarian aid.  It is an indication that both sides have agreed to a cessation of hostilities and are working towards addressing the humanitarian crisis in the region.',
#    'Article': 'm5vcc0dfsmuho41p'}],
#  [{'Date': '2023-09-08',
#    'Event': "Armenia accuses Azerbaijan of conducting a military build-up along the border of Nagorno-Karabakh and the Armenia-Azerbaijan border. Azerbaijan's foreign ministry rejects Armenia's assertion and accuses Yerevan of conducting military and political provocations. Azerbaijan's foreign policy adviser, Hikmet Hajiyev, confirms that Azerbaijan's armed forces are conducting pre-planned drills, but accuses Armenia of concentrating troops on the border and purchasing new weaponry systems. Russia criticizes Armenia's decision to host a joint exercise involving 85 US soldiers, stating that it does not contribute to stabilizing the situation in the region.",
#    'Contextual_Annotation': "This series of events represents a significant escalation of tensions between Armenia and Azerbaijan. Both sides accuse each other of military provocations, further intensifying the ongoing conflict over the Nagorno-Karabakh region.  This comes amidst a backdrop of ongoing negotiations for a peace deal and Azerbaijan's continued restrictions on movement along the only road to Nagorno-Karabakh from Armenia, which Azerbaijan claims is intended to prevent arms smuggling.  Russia, which plays a critical role as a security guarantor in the region, expressed concern over the increasing tensions and criticized Armenia's decision to host the US military exercise, deeming it unhelpful to the stabilization efforts.",
#    'Article': 'x6bs26mxih4wjnvb'}],
#  [{'Date': '2023-09-11',
#    'Event': 'Separatists in Karabakh refused to accept the cargo of a Russian Red Cross truck carrying aid, despite a deal announced with ethnic Armenian separatists to open the route for the first time in decades.',
#    'Contextual_Annotation': 'This incident highlights the ongoing tensions and mistrust between the separatists in Karabakh and the Azerbaijani government, despite the agreement to open the route for humanitarian aid.',
#    'Article': 'j40zdfvo5mm8yv3c'},
#   {'Date': '2023-09-12',
#    'Event': 'A Russian truck carrying food aid for Armenians in the Karabakh city of Khankendi set off via the Aghdam road, according to a Reuters witness and local media. Azerbaijan and Armenia agree to a third ceasefire, which is implemented with the support of Russia.',
#    'Contextual_Annotation': 'This signifies a significant step towards easing tensions and delivering humanitarian assistance to Armenians in Karabakh, amidst a backdrop of ongoing conflict between Azerbaijan and Armenia. The agreement for the ceasefire and the delivery of aid is a testament to the ongoing efforts of Russia to mediate and stabilize the situation in the region.',
#    'Article': 'j40zdfvo5mm8yv3c'}],
#  [{'Date': '2023-09-19',
#    'Event': 'Azerbaijan launched an offensive in the Nagorno-Karabakh region, claiming to be conducting "anti-terrorist measures of a local nature".',
#    'Contextual_Annotation': 'This marked a significant escalation of the conflict, with Azerbaijan initiating a military operation targeting Armenian-controlled territories. This offensive was triggered by Azerbaijan\'s claims of "terrorist provocations" by Armenian forces.',
#    'Article': 'bon7mzog28fpzkqk'}],
#  [{'Date': '2023-09-21',
#    'Event': "Armenian Prime Minister Nikol Pashinyan urges peace after Azerbaijan retakes Karabakh. Azerbaijan's President Ilham Aliyev expresses willingness for wider peace negotiations with Armenia. Pashinyan emphasizes the importance of peace for Armenian independence, sovereignty, and security.",
#    'Contextual_Annotation': "This statement comes after the fall of Nagorno-Karabakh, a region held by ethnic Armenian separatists for three decades, and amid calls for Pashinyan's resignation in Armenia. The loss of Karabakh has significantly impacted Armenia's political landscape and security, leading to a focus on peace efforts and the preservation of Armenian independence.",
#    'Article': '9owr18ngmcvsob4x'}],
#  [{'Date': '2023-09-25',
#    'Event': 'Petya Grigoryan, a 69-year-old driver, fled his village in the Martakert district of Karabakh after it was heavily bombed by Azerbaijani armed forces. Grigoryan said there were two KAMAZ-truckloads full of civilian dead in the village and that they had no place to bury them. He and his family were among the first ethnic Armenians of Nagorno-Karabakh to make it to Armenia after a lightning 24-hour Azerbaijani military operation defeated the Karabakh Armenian forces.',
#    'Contextual_Annotation': "Grigoryan's account highlights the devastating impact of the Azerbaijani military operation on the civilian population of Karabakh, leaving behind a scene of widespread destruction and death. This event marked the beginning of a mass exodus of Armenians from the region, as they feared for their safety and future in a region controlled by Azerbaijan.",
#    'Article': 'kgiisc7nhbtx8o7o'}]]

# %%
unsorted_timeline = []
for timeline in final_timeline:
    for event in timeline:
        unsorted_timeline.append(event)
unsorted_timeline
# Out:
# [{'Date': '2020-09-27',
#   'Event': 'Azerbaijan launched a large-scale offensive against the self-proclaimed Republic of Artsakh (Nagorno-Karabakh), resulting in a six-week war.',
#   'Contextual_Annotation': 'This marked the beginning of the Second Karabakh War, a conflict rooted in the historical dispute over the Nagorno-Karabakh region. The war was a result of decades of unresolved tensions between Armenia and Azerbaijan over the region, which had been under Armenian control since the 1990s following the collapse of the Soviet Union.',
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2020-11-10',
#   'Event': 'A tripartite ceasefire agreement was signed between Armenia, Azerbaijan, and Russia, ending the 2020 Nagorno-Karabakh war.',
#   'Contextual_Annotation': 'The ceasefire agreement resulted in Azerbaijan regaining control of significant territories in Nagorno-Karabakh and surrounding regions, including the city of Shusha, which is considered to be of great strategic and symbolic importance for Azerbaijan. The agreement also led to the deployment of Russian peacekeepers to the region to monitor the ceasefire and oversee the return of displaced persons.',
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2023-09-20',
#   'Event': 'Azerbaijan regained control of Nagorno-Karabakh after a three-decade-long Armenian occupation. Azerbaijani President Ilham Aliyev said he had given a strict order to all military units that the Armenian population living in the Karabakh region should not be affected by the anti-terrorist measures and that the civilian population be protected. Thousands of Armenians gathered at the airport in Stepanakert, Nagorno-Karabakh, following a ceasefire agreement that would result in the surrender of separatist forces to Azerbaijan. Several hundred protesters gathered in the Armenian capital to demand that the government do more to support ethnic Armenians in Nagorno-Karabakh.',
#   'Contextual_Annotation': "This marked a significant shift in the power dynamic, with Azerbaijan reclaiming control of Nagorno-Karabakh after decades of conflict. This event was precipitated by the breakdown of the 2020 ceasefire agreement and Azerbaijan's swift military operation. The event also highlights the humanitarian concerns and the reactions of the Armenian population. Thousands of Armenians fled Nagorno-Karabakh to Armenia fearing for their safety, highlighting the complex and sensitive nature of the situation.",
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2023-09-27',
#   'Event': 'Azerbaijan vowed to prosecute the separatist leadership of Nagorno-Karabakh.',
#   'Contextual_Annotation': "This indicates a shift in Azerbaijan's approach towards the separatists, aiming to hold them accountable for their actions during the conflict. Azerbaijan viewed the separatists as criminals and blamed them for poisoning the minds of the Armenian population.  This statement was made in the context of the swift military operation by Azerbaijan to regain control of Nagorno-Karabakh.",
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2023-10-04',
#   'Event': "Four ex-leaders of Nagorno-Karabakh were detained by Azerbaijan's State Security Service and taken to Baku. Three other former leaders of Nagorno-Karabakh arrived safely in Armenia.",
#   'Contextual_Annotation': "This signifies Azerbaijan's efforts to address the leadership of the separatist movement following their victory in the conflict. The detention of former leaders, including ex-president Arkady Gukasyan, Bako Sahakyan, and Araik Arutyunyan, highlights Azerbaijan's determination to hold them accountable for their actions.  The safe arrival of three other former leaders, including Artur Arutyunyan,  in Armenia adds a layer of complexity to the situation and raises questions about the fate of other former separatist leaders.",
#   'Article': '96moyhcopwdgflfi'},
#  {'Date': '2022-03-24',
#   'Event': 'Azerbaijan accuses Armenia of violating the ceasefire, sparking tensions between the two countries.',
#   'Contextual_Annotation': 'This marked a period of heightened tension following the ceasefire agreement, highlighting the fragility of the peace established after the 2020 war.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2022-08-03',
#   'Event': 'Clashes erupt between Armenian and Azerbaijani forces along the border, resulting in several casualties.',
#   'Contextual_Annotation': 'Further escalation of tensions between Armenia and Azerbaijan, underscoring the ongoing dispute over the Nagorno-Karabakh region.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-03-24',
#   'Event': 'Azerbaijan launches a military operation in Nagorno-Karabakh, seeking to regain control of the disputed territory.',
#   'Contextual_Annotation': 'This marked a renewed escalation in the conflict, with Azerbaijan launching a lightning offensive to retake control of the mountainous region, which they claim as their own.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-03-27',
#   'Event': 'Russia deploys peacekeepers to Nagorno-Karabakh to monitor the ceasefire.',
#   'Contextual_Annotation': "Russia's role as a peacekeeper in the region is highlighted, aiming to maintain a fragile peace amidst ongoing tensions.  This deployment followed the ceasefire agreement brokered by Russia.",
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-07-20',
#   'Event': 'Azerbaijan announces the capture of several villages in Nagorno-Karabakh.',
#   'Contextual_Annotation': 'This signifies a shift in the conflict, with Azerbaijan making territorial gains within the disputed region.  This move followed a months-long de facto blockade of the region.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-08-03',
#   'Event': 'Azerbaijan launches a new offensive in Nagorno-Karabakh.',
#   'Contextual_Annotation': "This indicates a significant escalation of the conflict, with Azerbaijan pushing further into the disputed territory after capturing several villages. This was labeled an 'anti-terrorist' operation by Azerbaijan.",
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-08-04',
#   'Event': 'Azerbaijan and Armenia agree to a new ceasefire, but it is violated within hours.',
#   'Contextual_Annotation': 'This highlights the fragility of any ceasefire agreements in the region, with ongoing hostilities despite attempts at peace. This ceasefire followed the offensive launched by Azerbaijan.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-09-24',
#   'Event': 'The ethnic Armenian leadership of breakaway Nagorno-Karabakh says the terms of the ceasefire with Azerbaijan are being implemented, with work proceeding on the delivery of humanitarian aid and evacuation of the wounded.',
#   'Contextual_Annotation': 'This marks a step towards normalcy in the region, with the implementation of the ceasefire agreement and the provision of humanitarian aid.  It is an indication that both sides have agreed to a cessation of hostilities and are working towards addressing the humanitarian crisis in the region.',
#   'Article': 'm5vcc0dfsmuho41p'},
#  {'Date': '2023-09-08',
#   'Event': "Armenia accuses Azerbaijan of conducting a military build-up along the border of Nagorno-Karabakh and the Armenia-Azerbaijan border. Azerbaijan's foreign ministry rejects Armenia's assertion and accuses Yerevan of conducting military and political provocations. Azerbaijan's foreign policy adviser, Hikmet Hajiyev, confirms that Azerbaijan's armed forces are conducting pre-planned drills, but accuses Armenia of concentrating troops on the border and purchasing new weaponry systems. Russia criticizes Armenia's decision to host a joint exercise involving 85 US soldiers, stating that it does not contribute to stabilizing the situation in the region.",
#   'Contextual_Annotation': "This series of events represents a significant escalation of tensions between Armenia and Azerbaijan. Both sides accuse each other of military provocations, further intensifying the ongoing conflict over the Nagorno-Karabakh region.  This comes amidst a backdrop of ongoing negotiations for a peace deal and Azerbaijan's continued restrictions on movement along the only road to Nagorno-Karabakh from Armenia, which Azerbaijan claims is intended to prevent arms smuggling.  Russia, which plays a critical role as a security guarantor in the region, expressed concern over the increasing tensions and criticized Armenia's decision to host the US military exercise, deeming it unhelpful to the stabilization efforts.",
#   'Article': 'x6bs26mxih4wjnvb'},
#  {'Date': '2023-09-11',
#   'Event': 'Separatists in Karabakh refused to accept the cargo of a Russian Red Cross truck carrying aid, despite a deal announced with ethnic Armenian separatists to open the route for the first time in decades.',
#   'Contextual_Annotation': 'This incident highlights the ongoing tensions and mistrust between the separatists in Karabakh and the Azerbaijani government, despite the agreement to open the route for humanitarian aid.',
#   'Article': 'j40zdfvo5mm8yv3c'},
#  {'Date': '2023-09-12',
#   'Event': 'A Russian truck carrying food aid for Armenians in the Karabakh city of Khankendi set off via the Aghdam road, according to a Reuters witness and local media. Azerbaijan and Armenia agree to a third ceasefire, which is implemented with the support of Russia.',
#   'Contextual_Annotation': 'This signifies a significant step towards easing tensions and delivering humanitarian assistance to Armenians in Karabakh, amidst a backdrop of ongoing conflict between Azerbaijan and Armenia. The agreement for the ceasefire and the delivery of aid is a testament to the ongoing efforts of Russia to mediate and stabilize the situation in the region.',
#   'Article': 'j40zdfvo5mm8yv3c'},
#  {'Date': '2023-09-19',
#   'Event': 'Azerbaijan launched an offensive in the Nagorno-Karabakh region, claiming to be conducting "anti-terrorist measures of a local nature".',
#   'Contextual_Annotation': 'This marked a significant escalation of the conflict, with Azerbaijan initiating a military operation targeting Armenian-controlled territories. This offensive was triggered by Azerbaijan\'s claims of "terrorist provocations" by Armenian forces.',
#   'Article': 'bon7mzog28fpzkqk'},
#  {'Date': '2023-09-21',
#   'Event': "Armenian Prime Minister Nikol Pashinyan urges peace after Azerbaijan retakes Karabakh. Azerbaijan's President Ilham Aliyev expresses willingness for wider peace negotiations with Armenia. Pashinyan emphasizes the importance of peace for Armenian independence, sovereignty, and security.",
#   'Contextual_Annotation': "This statement comes after the fall of Nagorno-Karabakh, a region held by ethnic Armenian separatists for three decades, and amid calls for Pashinyan's resignation in Armenia. The loss of Karabakh has significantly impacted Armenia's political landscape and security, leading to a focus on peace efforts and the preservation of Armenian independence.",
#   'Article': '9owr18ngmcvsob4x'},
#  {'Date': '2023-09-25',
#   'Event': 'Petya Grigoryan, a 69-year-old driver, fled his village in the Martakert district of Karabakh after it was heavily bombed by Azerbaijani armed forces. Grigoryan said there were two KAMAZ-truckloads full of civilian dead in the village and that they had no place to bury them. He and his family were among the first ethnic Armenians of Nagorno-Karabakh to make it to Armenia after a lightning 24-hour Azerbaijani military operation defeated the Karabakh Armenian forces.',
#   'Contextual_Annotation': "Grigoryan's account highlights the devastating impact of the Azerbaijani military operation on the civilian population of Karabakh, leaving behind a scene of widespread destruction and death. This event marked the beginning of a mass exodus of Armenians from the region, as they feared for their safety and future in a region controlled by Azerbaijan.",
#   'Article': 'kgiisc7nhbtx8o7o'}]

# %%
sorted_events = sorted(unsorted_timeline, key=lambda x: x['Date'])
json_data = json.dumps(sorted_events, indent=4, ensure_ascii=False)

# Write the JSON string to a file
with open('../data_upload/enhanced_timeline_trial.json', 'w', encoding='utf-8' ) as fin:
    fin.write(json_data)
