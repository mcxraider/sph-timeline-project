# %%
from pymongo import MongoClient
import os
from dotenv import load_dotenv
load_dotenv()
MONGO_URL = os.environ['MONGO_URL']

# Connect to the MongoDB client
mongo_client = MongoClient(MONGO_URL)

# %%
db = mongo_client['timeline-project']
test_article_collection = db['test-articles']
train_art_documents = db['test-articles'].inser
gen_timeline_collection = db['generated-timelines']

# %%
t = {"Article_id": "test insert", "Timeline": "null"}
gen_timeline_collection.insert_one(t)
# Out:
# InsertOneResult(ObjectId('6662bf903a80ea81a577c85f'), acknowledged=True)

# %%
gen_timeline_collection.delete_one({"Article_id": "test insert"})
# Out:
# DeleteResult({'n': 1, 'ok': 1.0}, acknowledged=True)

# %%
import json
with open("../data_upload/gradio/train_articles.json", "r", encoding='utf-8') as fin:
            test_database = json.load(fin)

# %%
test_database[0]
# Out:
# {'id': 'rvpz25o6382en0dc',
# ...
